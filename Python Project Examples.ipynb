# %%
import requests
from bs4 import BeautifulSoup

url ='https://kenpom.com/'
r = requests.get(url).text
soup = BeautifulSoup(r, 'lxml')

import pandas as pd
import numpy as np
import warnings
import matplotlib
import matplotlib.pyplot as plt
import plotly 
#import plotly.plotly as py     
import plotly.graph_objs as go  
#import cufflinks as cf
import pandas as pd
import folium
import warnings
import plotly.express as px
warnings.filterwarnings('ignore')


#Random Sample of data
basketball = pd.read_csv('kenpom.csv')
basketball.sample(10)

#Shows we can call conferences
basketball['Conf'].sample(10)

Conf = basketball['Conf'].value_counts()
Conf
conf_df = pd.DataFrame( { 'Conf' : Conf.index,  "Conf" : Conf })
conf_df
conf_df.plot.pie( y = 'Conf')

# %%
basketball = pd.read_csv('python_basketball2.csv')
print(basketball)

def print_menu():
    print("R - Rank")
    print("C - Conference")
    print("W - W-L")
    print("E - AdjEM")
    print("O - AdjO")
    print("D - AdjD")
    print("Z - AdjT")
    print("L - Luck")
    print("SE - SOS AdjEM")
    print("SO - SOS OppO")
    print("SD - SOS OppD")
    print("N - NCSOS AdjEM")
    print("Q - Quit")
    return

def rank(category):
    print("Type quit to exit this section. ")
    while True:
        team = input("Enter an team: ")
        if team in basketball:
            print('hello')
        elif team == 'quit':
            False
            break
        
def conf(category):
    print("Type quit to exit this section. ")
    while True:
        team = input("Enter an team: ")
        team = team.lower()
        if team in basketball:
            print(basketball[Conf])
        elif team == 'quit':
            False
            break     
        
def W_L(category):
    print("Type quit to exit this section. ")
    while True:
        team = input("Enter an team: ")
        team = team.lower()
        if team in basketball:
            print(basketball[W-L])
        elif team == 'quit':
            False
            break
        
def AdjEM(category):
    print("Type quit to exit this section. ")
    while True:
        team = input("Enter an team: ")
        team = team.lower()
        if team in basketball:
            print(basketball[AdjEM])
        elif team == 'quit':
            False
            break
        
def AdjO(category):
    print("Type quit to exit this section. ")
    while True:
        team = input("Enter an team: ")
        team = team.lower()
        if team in basketball:
            print(basketball[AdjO])
        elif team == 'quit':
            False
            break
        
def AdjD(category):
    print("Type quit to exit this section. ")
    while True:
        team = input("Enter an team: ")
        team = team.lower()
        if team in basketball:
            print(basketball[AdjD])
        elif team == 'quit':
            False
            break  
        
def AdjT(category):
    print("Type quit to exit this section. ")
    while True:
        team = input("Enter an team: ")
        team = team.lower()
        if team in basketball:
            print(basketball[AdjT])
        elif team == 'quit':
            False
            break
            
def SOSAdjEM(category):
    print("Type quit to exit this section. ")
    while True:
        team = input("Enter an team: ")
        team = team.lower()
        if team in basketball:
            print(basketball[SOSAdjEM])
        elif team == 'quit':
            False
            break
        
def SOSOppO(category):
    print("Type quit to exit this section. ")
    while True:
        team = input("Enter an team: ")
        team = team.lower()
        if team in basketball:
            print(basketball[SOSOppO])
        elif team == 'quit':
            False
            break
        
def SOSOppD(category):
    print("Type quit to exit this section. ")
    while True:
        team = input("Enter an team: ")
        team = team.lower()
        if team in basketball:
            print(basketball[SOSOppD])
        elif team == 'quit':
            False
            break

def NCSOSAdgEM(category):
    print("Type quit to exit this section. ")
    while True:
        team = input("Enter an team: ")
        team = team.lower()
        if team in basketball:
            print(basketball[NCSOSAdgEM])
        elif team == 'quit':
            False
            break

## Main Program Written For You
category = []
while True:
    print_menu()
    choice = input("Enter choice: ").upper()
    if choice == 'R':
        shopping_list = rank(category)
    elif choice == 'C':
        shopping_list = conf(category)
    elif choice == 'W':
        shopping_list = W_L(category)
    elif choice == 'E':
        shopping_list = AdjEM(category)
    elif choice == 'O':
        shopping_list = AdjO(category)
    elif choice == 'D':
        shopping_list = AdjD(category)
    elif choice == 'Z':
        shopping_list = AdjT(category)
    elif choice == 'L':
        shopping_list = Luck(category)    
    elif choice == 'SE':
        shopping_list = SOSAdjEM(category)
    elif choice == 'SO':
        shopping_list = SOSOppO(category)
    elif choice == 'SD':
        shopping_list = SOSOppD(category)
    elif choice == 'N':
        shopping_list = NCSOSAdjEM(category)
    elif choice == "Q":
        break
    else:
        print('ERROR:', choice,'is not a menu option')
print("The program has ended.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d7dacc6d1a74> in <module>
# ----> 1 basketball = pd.read_csv('python_basketball2.csv')
#       2 print(basketball)
#       3
#       4 def print_menu():
#       5     print("R - Rank")
#
# NameError: name 'pd' is not defined

# %%
! pip install beautifulsoup4
from bs4 import BeautifulSoup
# Out:
# Collecting beautifulsoup4
#   Downloading https://files.pythonhosted.org/packages/3b/c8/a55eb6ea11cd7e5ac4bacdf92bac4693b90d3ba79268be16527555e186f0/beautifulsoup4-4.8.1-py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 4.9MB/s ta 0:00:011
# Collecting soupsieve>=1.2 (from beautifulsoup4)
#   Downloading https://files.pythonhosted.org/packages/81/94/03c0f04471fc245d08d0a99f7946ac228ca98da4fa75796c507f61e688c2/soupsieve-1.9.5-py2.py3-none-any.whl
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.8.1 soupsieve-1.9.5

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np

url = "https://kenpom.com/index.php?y="
r = requests.get(url).text
soup = BeautifulSoup(r, 'lxml')
data = [s.text for s in soup.select("td")]
print(data[:20])


url = "https://kenpom.com/index.php?y="
r = requests.get(url).text
soup = BeautifulSoup(r, 'lxml')
teams = [s.text for s in soup.select("td.next_left")]
print(teams[:20])
# Out:
# ['1', 'Ohio St.', 'B10', '9-0', '+29.15', '113.6', '7', '84.4', '2', '66.1', '304', '+.003', '160', '+0.44', '180', '101.4', '113', '101.0', '236', '-1.62']
# ['Ohio St.', 'Louisville', 'Duke', 'Michigan St.', 'Kansas', 'Purdue', 'Kentucky', 'Maryland', 'Gonzaga', 'Virginia', 'Michigan', 'Baylor', 'Butler', 'Oregon', 'Florida St.', 'Auburn', 'Seton Hall', 'Arizona', 'Villanova', 'Dayton']

# %%
# Out:
# []
